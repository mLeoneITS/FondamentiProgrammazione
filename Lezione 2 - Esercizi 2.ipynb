# %% [markdown]
# ***Esercizio 1***: Scrivi un programma che usi input per chiedere all’utente il proprio
# nome e poi dia loro il benvenuto.

# %% [markdown]
# ***Esercizio 2***: Scrivi un programma per richiedere all’utente ore di lavoro e tariffe
# orarie per calcolare la retribuzione lorda.
# Per ora non ci preoccuperemo di assicurarci che la paga abbia esattamente due
# cifre dopo la virgola. Se vuoi, puoi giocare con la funzione round di Python per
# arrotondare correttamente la retribuzione risultante a due cifre decimali.

# %% [markdown]
# ***Esercizio 3***: Supponiamo di eseguire le seguenti istruzioni di assegnazione:
# ```
# width = 17
# height = 12.0
# ```
#
# Per ciascuna delle seguenti espressioni, scrivi il valore dell’espressione e il tipo di
# dato (del valore dell’espressione).
# 1. `width//2`
# 2. `width/2.0`
# 3. `height/3`
#
# Utilizza l’interprete Python per verificare le tue risposte.

# %%
width = 17
height = 12.0

# %% [markdown]
# ***Esercizio 4***: Scrivi un programma che, richiesta all’utente una temperatura in
# gradi Celsius, la converta in Fahrenheit e poi la visualizzi.

# %% [markdown]
# **STEP 1:**
# Scrivi uno script che prenda in input 2 numeri, e stampi
# - la loro somma
# - la loro differenza
# - il loro prodotto
# - la loro divisione
# - la parte intera della divisione
# - il resto della divisione
#
# **STEP 2:**
# Prendi in input 3 numeri invece che 2
#
# **STEP 3:**
# Stampa ANCHE la somma di tutti i risultati parziali (addizione + sottrazione +.....+ resto della divisione)
